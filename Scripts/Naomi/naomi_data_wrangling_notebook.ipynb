# %% [markdown]
# Data Wrangling Notebook for Additional Deer Data
# <br />
# Neeka Sewnath
# <br />
# nsewnath@ufl.edu

# %%
import pandas as pd

# %% [markdown]
# In order to piece together the database, I'm thinking we just need one to start building on

# %%
#Base data
deer_data = pd.read_csv("bone.csv")

# %% [markdown]
# I chose deer data because I'm hoping bone ID refers to each individual element and there for will be the limiting factor here. I'm going to continue in order and assess what needs to be matched. I don't really know where this one fits so I'll keep going for now.

# %%
#TODO: figure out where this fits
assemblage = pd.read_csv("assemblage.csv")

# %%
#TODO: figure out where this fits
bone_measurement = pd.read_csv("bone_measurement.csv")

# %%
#TODO: figure out where this fits
context = pd.read_csv("context.csv")

# %%
bone_type = pd.read_csv("bone_type.csv")

# %% [markdown]
# We can definitely work with this one. If there is a match between the two data sets then fill the bone type with the correct name

# %%
#Create bone_type column in deer_data
deer_data=deer_data.assign(bone_type_name="")

#Find match, if there's a match, assign bone type
for i in deer_data["bone_type_id"].index:
    for j in bone_type["bone_type_id"].index:
        if deer_data["bone_type_id"][i] == bone_type["bone_type_id"][j]:
            deer_data["bone_type_name"][i] = bone_type["bone_type_name"][j]
# Out:
# <ipython-input-75-ee491b5e91b0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["bone_type_name"][i] = bone_type["bone_type_name"][j]

# %%
reference = pd.read_csv("reference.csv")
reference
# Out:
#     reference_id                                  reference_details  \
# 0              1  Albarella, U. &#038; Davis, S. 1996. Mammals a...
# 1              2  Albarella, U., Beech, M. &#038; Mulville, J. 1...
# 2              3              Arbuckle, B.  Personal communication.
# 3              4  Ayre, K. &#038; Serjeantson, D. 2002. The Anim...
# 4              5  Ayres, K., Ingrem, C., Light, J., Locker, A., ...
# ..           ...                                                ...
# 95            95  Parfitt, S. 1988. The animal bones. In M. Gard...
# 96            96  Prummel, W. 1977. Een bewerkt damhertbeen uit ...
# 97            97  Rahtz, P. 1977. Fauna. In P. Rahtz &#038; E. G...
# 98            98  Rauh, H. 1981. <em>Knochenfunde von S&#228;uge...
# 99            99  Reichstein, H. 1979. Erste ergebnisse von unte...
#
#    created_by         created_date modified_by        modified_date
# 0      acznjs  2009-11-20 00:00:00       aczjd  2016-07-02 00:00:00
# ...

# %% [markdown]
# Do the same matching scheme again with the references

# %%
#Create reference column in deer_data
deer_data=deer_data.assign(reference="")

#Find match, if there's a match, assign bone type
for i in deer_data["reference_id"].index:
    for j in reference["reference_id"].index:
        if deer_data["reference_id"][i] == reference["reference_id"][j]:
            deer_data["reference"][i] = reference["reference_details"][j]

#Note: a lot of the references are missing.
# Out:
# <ipython-input-77-780f941478ce>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["reference"][i] = reference["reference_details"][j]

# %% [markdown]
# Moving on to site.csv, which will have the same mechanisms, be a little more involved, but have a lot of pieces of the puzzle!

# %%
site = pd.read_csv("site.csv")

# %%
#Create site columns in deer_data
deer_data=deer_data.assign(site_name="")
deer_data=deer_data.assign(country_code="")
deer_data=deer_data.assign(region="")
deer_data=deer_data.assign(location="")

#Find match, if there's a match, assign bone type
for i in deer_data["site_code"].index:
    for j in site["site_code"].index:
        if deer_data["site_code"][i] == site["site_code"][j]:
            deer_data["site_name"][i] = site["site_name"][j]
            deer_data["country_code"][i] = site["country_code"][j]
            deer_data["region"][i] = site["region"][j]
            deer_data["location"][i] = site["location"][j]
# Out:
# <ipython-input-79-3b67efecec65>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["site_name"][i] = site["site_name"][j]
# <ipython-input-79-3b67efecec65>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["country_code"][i] = site["country_code"][j]
# <ipython-input-79-3b67efecec65>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["region"][i] = site["region"][j]
# ...

# %% [markdown]
# Now we can move on to country code

# %%
country = pd.read_csv("country.csv")

# %%
#Create country column in deer_data
deer_data=deer_data.assign(country_name="")

#Find match, if there's a match, assign bone type
for i in deer_data["country_code"].index:
    for j in country["country_code"].index:
        if deer_data["country_code"][i] == country["country_code"][j]:
            deer_data["country_name"][i] = country["country_name"][j]
# Out:
# <ipython-input-81-e109503c5978>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["country_name"][i] = country["country_name"][j]

# %% [markdown]
# We can do the same method for species id

# %%
species = pd.read_csv("species.csv")

# %%
#Create species column in deer_data
deer_data=deer_data.assign(common_name="")
deer_data=deer_data.assign(latin_name="")

#Find match, if there's a match, assign bone type
for i in deer_data["species_id"].index:
    for j in species["species_id"].index:
        if deer_data["species_id"][i] == species["species_id"][j]:
            deer_data["common_name"][i] = species["common_name"][j]
            deer_data["latin_name"][i] = species["latin_name"][j]
# Out:
# <ipython-input-83-d401f7be2599>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["common_name"][i] = species["common_name"][j]
# <ipython-input-83-d401f7be2599>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["latin_name"][i] = species["latin_name"][j]

# %% [markdown]
# Moving on to period id

# %%
period = pd.read_csv("period.csv")
period
# Out:
#     period_id              period_name  sequence_number
# 0           1     Mesolithic/Neolithic                2
# 1           2                Neolithic                3
# 2           3     Neolithic/Bronze Age                4
# 3           4               Bronze Age                5
# 4           5      Bronze Age/Iron Age                6
# 5           6                 Iron Age                7
# 6           7           Iron Age/Roman                8
# 7           8                    Roman                9
# 8           9           Early Medieval               10
# 9          10  Early Medieval/Medieval               11
# 10         11                 Medieval               12
# 11         12            Post Medieval               13
# 12         13                   Modern               14
# 13         14             Palaeolithic                1

# %%
#Create period columns in deer_data
deer_data=deer_data.assign(period_name="")
deer_data=deer_data.assign(sequence_number="")

#Find match, if there's a match, assign bone type
for i in deer_data["period_id"].index:
    for j in period["period_id"].index:
        if deer_data["period_id"][i] == period["period_id"][j]:
            deer_data["period_name"][i] = period["period_name"][j]
            deer_data["sequence_number"][i] = period["sequence_number"][j]
# Out:
# <ipython-input-85-c408340e3b0d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["period_name"][i] = period["period_name"][j]
# <ipython-input-85-c408340e3b0d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deer_data["sequence_number"][i] = period["sequence_number"][j]

# %%
deer_data
# Out:
#    site_code  reference_id  period_id  bone_id  species_id  bone_type_id  \
# 0    AB78L01           152          8        1           1            23
# 1    ABRID01           170         14        1           4             3
# 2    ABRID01           170         14        2           4             4
# 3    ABRID01           170         14        3           4             5
# 4    ABRID01           170         14        4           4             5
# ..       ...           ...        ...      ...         ...           ...
# 95   ALON001           180          4        1           5             3
# 96   ALON001           180          4        2           5             3
# 97   ALON001           180          4        3           5             3
# 98   ALON001           180          4        4           5             3
# 99   ALON001           180          4        5           5             3
#
#                             bone_date  position gender  age  ... reference  \
# ...

# %% [markdown]
# I might be able to do assemblage next, then followed by context, but I'd have to match two. measurement_type also needs to be addressed but that should be easy once bone tables are fixed. Add site.csv

# %%
This gets tricky. There are multiple bone_ids.
