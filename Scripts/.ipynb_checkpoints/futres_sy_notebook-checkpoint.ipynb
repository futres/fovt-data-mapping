# %% [markdown]
# Data Wrangling Notebook for SY Data
# <br />
# Neeka Sewnath
# <br />
# nsewnath@ufl.edu

# %%
import pandas as pd
import numpy as np
import re
import uuid

# %% [markdown]
# Import Vertnet Mammal Data

# %%
sy_data = pd.read_csv("./../Original Data/futres_sy_original.csv")

# %% [markdown]
# Subset test data

# %%
test = sy_data[sy_data.columns[-3:]]
test
# Out:
#                    PROTOCOL Measurements (NAME;NAME;NAME...) divided by ;  \
# 0   L'Hereux y Borella 2011                                         Bd;Dd
# 1    Von den Driesch (1976)                                GL;Bp;Bd;Dp;Dd
# 2    Von den Driesch (1976)                                  PL;BFcr;HFcr
# 3    Von den Driesch (1976)                                            PL
# 4   L'Hereux y Borella 2011                                         Bp,Dp
# 5   L'Hereux y Borella 2011                                            Dd
# 6    Von den Driesch (1976)                            GL;La;Dip;SC;Bd;Dd
# 7    Von den Driesch (1976)                          GL;La;Dip;SC;Bd*;Dd*
# 8    Von den Driesch (1976)                                         Bd;Dd
# 9    Von den Driesch (1976)                          GL;Lm;Bp;Dp;SC;Bd;Dd
# 10   Von den Driesch (1976)                          GL;Lm;Bp;Dp;SC;Bd;Dd
# 11   Von den Driesch (1976)                                   GL;Bp;SC;Bd
# 12   Von den Driesch (1976)                              GL;Dip;Bp;SC;Did
# 13   Von den Driesch (1976)                                           DiA
# 14   Von den Driesch (1976)                                           DiA
# 15   Von den Driesch (1976)                                      SD;Bd;Dd
# 16   Von den Driesch (1976)                                      Bp;DC;SD
# 17   Von den Driesch (1976)                                  GL;GLC;Bp;DC
# 18   Von den Driesch (1976)                                         SD;Bd
# 19   Von den Driesch (1976)                                  LA;LAR;SH;SB
#
#    Values (mm;mm;mm...) divided by ;
# 0                          29,5;17,2
# 1                       14;4,5;4;4;2
# 2                          7;4,5;2,2
# 3                               13,1
# 4                          27,5;22,2
# 5                                 19
# 6             47,2;46,8;7;2,9;4;3,85
# 7                    47;46,3;7,1;2,5
# 8                              4;3,9
# 9           26,5;25;4,9;2,9;2;5,25;3
# 10           26,4;24,9;5;3;1,9;5,3;3
# 11                    35;4,1;1,7;3,6
# 12                21,2;3,5;3,8;1,4;3
# 13                               2,1
# 14                               2,1
# 15                         3,4;3,7;3
# 16                      11,4;3,6;3,4
# 17               33,2;32,45;7,8;3,75
# 18                           3,5;5,6
# 19                     4,3;4;3,6;2,6

# %% [markdown]
# Rename Columns

# %%
test = test.rename(columns={'Measurements (NAME;NAME;NAME...) divided by ;':'measurementType',
                            'Values (mm;mm;mm...) divided by ;': 'measurementValue',
                            'PROTOCOL':'protocol'})

# %% [markdown]
# Separate by ; and expand

# %%
test_new_val = test.join(test.pop('measurementValue').str.split(';',expand=True))
test_new_val = test_new_val.set_index(['protocol','measurementType']).stack().reset_index(level=[0,1],name='measurementValue')

# %%
test_new_type = test.join(test.pop('measurementType').str.split(';',expand=True))
test_new_type = test_new_type.set_index(['protocol','measurementValue']).stack().reset_index(level=[0,1],name='measurementType')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1ea05ac3d169> in <module>
#       1 test_new_type = test.join(test.pop('measurementType').str.split(';',expand=True))
# ----> 2 test_new_type = test_new_type.set_index(['protocol','measurementValue']).stack().reset_index(level=[0,1],name='measurementType')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4546
#    4547         if missing:
# -> 4548             raise KeyError(f"None of {missing} are in the columns")
#    4549
#    4550         if inplace:
#
# KeyError: "None of ['measurementValue'] are in the columns"

# %%
test_new_val
# Out:
#                    protocol measurementType measurementValue
# 0   L'Hereux y Borella 2011           Bd;Dd             29,5
# 1   L'Hereux y Borella 2011           Bd;Dd             17,2
# 0    Von den Driesch (1976)  GL;Bp;Bd;Dp;Dd               14
# 1    Von den Driesch (1976)  GL;Bp;Bd;Dp;Dd              4,5
# 2    Von den Driesch (1976)  GL;Bp;Bd;Dp;Dd                4
# ..                      ...             ...              ...
# 1    Von den Driesch (1976)           SD;Bd              5,6
# 0    Von den Driesch (1976)    LA;LAR;SH;SB              4,3
# 1    Von den Driesch (1976)    LA;LAR;SH;SB                4
# 2    Von den Driesch (1976)    LA;LAR;SH;SB              3,6
# 3    Von den Driesch (1976)    LA;LAR;SH;SB              2,6
#
# [67 rows x 3 columns]
